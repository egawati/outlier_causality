# %%
import numpy as np
import pandas as pd

from dowhy import gcm
from dowhy.gcm import MedianCDFQuantileScorer

from ocular.causal_model import dag

# %%
nodes = [('X1', 'X2'), ('X2', 'X3'), ('X3', 'X4'), ('X4', 'X5')]
features = ['X1', 'X2', 'X3', 'X4', 'X5']
target_node = 'X5'
error_threshold_change=0.05
causal_graph = dag.CausalGraph(nodes, features)
all_ancestors_of_node = causal_graph.ancestors[target_node]
all_ancestors_of_node.update({target_node})
sorted_nodes = [node for node in causal_graph.sorted_nodes if node in all_ancestors_of_node]

# %%
def train_models(data_sample, causal_graph, sorted_nodes):
    models = {}
    for node in sorted_nodes:
        parents = causal_graph.parents[node]
        ## if a node is a root
        if not parents:
            ## initialize model for root node and fit the distribution
            models[node] = gcm.ScipyDistribution()
            X = data_sample[node].to_numpy()
            #print(f'Does X contains nan value? {np.isnan(X).any()}')
            print(f"Test X for finiteness {np.isfinite(X).all()}")
            models[node].fit(X=X)
            print('done fitting gcm.ScipyDistribution()')
        else:
            #logging.info(f'at node {node} with parents {parents}')
            fm_model = gcm.AdditiveNoiseModel(gcm.ml.create_linear_regressor())
            fm_model.fit(X=data_sample[parents].to_numpy(), Y=data_sample[node].to_numpy())

            ## set the first model
            models[node] = fm_model

# %%
data_sample = pd.read_csv('test_nslide3_1.csv')
models = train_models(data_sample, causal_graph, sorted_nodes)
# Out:
# Test X for finiteness True
# self.find_suitable_continuous_distribution(X)
# x_neighbourhood input (151, 1)
# y_neighbourhood input(151, 1)
# finally found the suitable distribution
# done fitting gcm.ScipyDistribution()
# Fitting emperical model
# Fitting emperical model
# Fitting emperical model
# Fitting emperical model

# %%
data_sample = pd.read_csv('test_nslide3_2.csv')
models = train_models(data_sample, causal_graph, sorted_nodes)
# Out:
# Test X for finiteness True
# self.find_suitable_continuous_distribution(X)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# y_neighbourhood input(301, 1)
# x_neighbourhood input (301, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 data_sample = pd.read_csv('test_nslide3_2.csv')
# ----> 2 models = train_models(data_sample, causal_graph, sorted_nodes)
#
# Cell In[3], line 12, in train_models(data_sample, causal_graph, sorted_nodes)
#      10     #print(f'Does X contains nan value? {np.isnan(X).any()}')
#      11     print(f"Test X for finiteness {np.isfinite(X).all()}")
# ---> 12     models[node].fit(X=X)
#      13     print('done fitting gcm.ScipyDistribution()')
#      14 else:
#      15     #logging.info(f'at node {node} with parents {parents}')
#
# File ~/Projects/Codes/causality/dowhy/dowhy/gcm/stochastic_models.py:78, in ScipyDistribution.fit(self, X)
#      75 if self._distribution is None:
#      76     # Currently only support continuous distributions for auto selection.
#      77     print(f'self.find_suitable_continuous_distribution(X)')
# ---> 78     best_model, best_parameters = self.find_suitable_continuous_distribution(X)
#      79     print(f'finally found the suitable distribution')
#      80     self._distribution = best_model
#
# File ~/Projects/Codes/causality/dowhy/dowhy/gcm/stochastic_models.py:136, in ScipyDistribution.find_suitable_continuous_distribution(distribution_samples, divergence_threshold)
#     133 generated_samples = distribution.rvs(size=distribution_samples.shape[0], loc=loc, scale=scale, *arg)
#     135 # Check the KL divergence between the distribution of the given and fitted distribution.
# --> 136 divergence = estimate_kl_divergence_continuous(distribution_samples, generated_samples)
#     137 if divergence < divergence_threshold:
#     138     currently_best_distribution = distribution
#
# File ~/Projects/Codes/causality/dowhy/dowhy/gcm/divergence.py:63, in estimate_kl_divergence_continuous(X, Y, k, remove_common_elements)
#      61 x_neighbourhood = NearestNeighbors(n_neighbors=k + 1).fit(X)
#      62 print(f'x_neighbourhood input {X.shape}')
# ---> 63 y_neighbourhood = NearestNeighbors(n_neighbors=k).fit(Y)
#      64 print(f'y_neighbourhood input{Y.shape}')
#      66 distances_x, _ = x_neighbourhood.kneighbors(X, n_neighbors=k + 1)
#
# File ~/opt/anaconda3/envs/outlier_causal/lib/python3.8/site-packages/sklearn/neighbors/_unsupervised.py:175, in NearestNeighbors.fit(self, X, y)
#     158 def fit(self, X, y=None):
#     159     """Fit the nearest neighbors estimator from the training dataset.
#     160
#     161     Parameters
#    (...)
#     173         The fitted nearest neighbors estimator.
#     174     """
# --> 175     return self._fit(X)
#
# File ~/opt/anaconda3/envs/outlier_causal/lib/python3.8/site-packages/sklearn/neighbors/_base.py:444, in NeighborsBase._fit(self, X, y)
#     442 else:
#     443     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 444         X = self._validate_data(X, accept_sparse="csr", order="C")
#     446 self._check_algorithm_metric()
#     447 if self.metric_params is None:
#
# File ~/opt/anaconda3/envs/outlier_causal/lib/python3.8/site-packages/sklearn/base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~/opt/anaconda3/envs/outlier_causal/lib/python3.8/site-packages/sklearn/utils/validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~/opt/anaconda3/envs/outlier_causal/lib/python3.8/site-packages/sklearn/utils/validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').

# %%
data_sample = pd.read_csv('test_nslide3_3.csv')
models = train_models(data_sample, causal_graph, sorted_nodes)
